# %% [markdown]
# # My Notes
#
# Source: Data Warehouse Toolkit: Third Edition Book
#
# Note that this Book has Data warehousing Modeling for all types of industries: from Retail to Accounting. So in order to see Datawarehousing for particular type of industry pick the industry from chapter 3 to Chapter 16.

# %% [markdown]
# # LECTURE 1 : DIMESNIONAL MODELING PART 1
#
#
#
# ## 1. Why DW/BI?
#
# - One of the most important assets of any organization is its
# information. This asset is almost always used for two
# purposes: operational record keeping and analytical decision
# making.
#
#
# #Simply speaking, the operational systems are
# where you put the data in, and the DW/BI system is where
# you get the data out.
#
#
# - While operational Data gives us information of each transaction. DW/BI generates system to use selceted data from operational data to answer certain question of clients and evaluate business.
#
#
# ## 2. Goals of Data Warehousing and Business Intelligence
#
# The Goals are simplle: Answer age old questions of business managment.
#
#
# - “We collect tons of data, but we can't access it.”
# - “We need to slice and dice the data every which way.”
# - “Business people need to get at the data easily.”
# - “Just show me what is important.”
# - “We spend entire meetings arguing about who has the right numbers rather than making decisions.”
# - “We want people to use information to support more fact-based decision making.”
#
#
# ## 3. Dimensional Modeling Introduction
#
# Dimensional
# modeling is a preferred technique for
# presenting analytic data because it addresses two
# simultaneous requirements:
#
#
#
# ## 4. What is the difference between dimensional Modeling and STAR SCHEMA?
#
# - Dimensional Modeling means to arrange the data(Model) in a datawarehouse. There are mutliple ways to Model the data.
# - One of the Method to do Dimenisal Modeling is STAR SCHEMA.
#
#
# ##  5. Why do People Confuse Dimensional Modeling with 3NF Relational Tables
#
# - Dimensional models are quite different from third normal form (3NF) models which seek to remove data redundancies. Normalized 3NF structures divide data into many discrete entities.
#
#
# - Also, The industry sometimes refers to 3NF models as (ER) models, which are drawings that communicate the relationships between tables. Both 3NF and dimensional models can be represented in ERDs because both consist of joined relational tables.
#
#
# - The key difference between 3NF and dimensional models is the degree of normalization. Because both model types can be presented as ERDs, we refrain from referring to 3NF models as ER models; instead, we call them normalized models to minimize confusion.
#
#
# - Normalized 3NF structures are immensely useful in operational processing because an update or insert transaction touches the database in only one place. Normalized models, however, are too complicated for BI queries.
#
#
# - **A dimensional model contains the same information as a normalized model, but packages the data in a format that delivers user understandability, query performance, and resilience to change**
#
#
#
#
# ## 6.? What are the Goals of making Data warehouse?
#
# The Main Aim of Data Warehousing is to use the data recorded from opertaional activitie.The Goals of this warehouse are:
#
#
# 1. Making Data Acceble to Everyone.
# 2. Keeping Data consistent (reliable such as common labelling)
# 3. It should adapt to chnage. Menaing existing data shoud noterupt with changes in data.
# 4. It should be in DataWarehouse Timely.
# 5. Data is secured in Data warehouse.
# 6. Should have TrustWorthy Data.
#
#
#
# ## 7. What are the Steps for Dimensional Modeling (STAR SCHEMA)?
#
# - Identify the Busines Process
# - Identify the level of Granularity
# - identify Dimesnions
# - Idnetify the Facts
#
# Please Note that All attributes in a Dimesnial table are recognised by Primary Key, and this primary Key of Dimesnional Table is always a Foriegn Key in the Fact Table.
#
#
# Example:
# ![image.png](attachment:image.png)

# %% [markdown]
# # Lecture 2
#
# ## 1. What are the Type of Facts?
#
# - Additive Facts: They give meaningful value on Addition such as Quantity across all dimesnions .
# - Semi Additive: Semi Additive Facts give valuable meaning only for few dimesnions.
# - Non Additive: Does not give any value on addition such as Unitr price of a Product.
#
# Please note that Unit Price or Discount Price are always Non-Additive Facts.
#
#
#
#
# ## 2. Why do we keep DateDim Table in our STAR Scema instead of Time Stamp in Fact table?
#
# - Time Stamp in Fact Table will cause problems in Identifying day of Date or other attributes wich respect to a date such as hoiliday.So Time stamp will have to fist convert into Calnder Year to extract such information and that will take computational cost.
# - Hence, Its better to kepp a Date Dimemsnion in the data modeling
#
#
#
# ## 3. Should we keep Date and Time in One table ?
#
# - No
# - We should only keep date, day, Month and Year in Date Dimesnional Table(calender year or Fiscal Year)
# - We should have separate Table for Time
# - If we keep time in minutes or second, then combine data and time table will have too many rows and we dont need that.
#
#
# ## 4. What is Degenrate Key ?
# According to Ralph Kimball, in a data warehouse, a degenerate dimension is a dimension key in the fact table that does not have its own dimension table.
#
#
# ## 5. What is surrogate Key?
#
# A surrogate key (or synthetic key, pseudokey, entity identifier, factless key, or technical key) in a database is a unique identifier for either an entity in the table when natural Primary key can not be used as Primary Key due to business requirments.
#
#
# ## 6. How to extend Star Schemas?
#
# - A star schema or any Data Modeling method cab be extended from new data by adding more dimensions or adding new attributes in existing dimesnions or adding new fcats in the Fact table. It all depens upon identifying where does new data belong.
#
#
# ## 7. Can a Schema be Fact Less?
#
# - Yes a schema can be Fcatless. But it will still have fact table with all foriegn keys from Dimesnional Table.
#
# ![image.png](attachment:image.png)
#
# ## 8. What are the advantages of using surrogate Key over Natural Primary Key
#
# - Natural Keys are naturally unique column in a trasnactuional data table such as SKU or SSN. But Surrogate key are genrated integer key which helps you to identfy data in data warehousing. A change in natural key can impact the table but surrgate key value is never changed.
#
# - It also helps in traching slowly chnage Dimesnion.

# %% [markdown]
# # Lecture 3: Enterprise DW Architecture
#
#
# ## 1 What is Value Chain?
#
# “The value chain describes the full range of activities that firms and workers do to bring a product from its conception to its end use and beyond. This includes activities such as design, production, marketing, distribution and support to the final consumer.
#
# In Value Chain, we will have different schema for different part of value chain. such as Sales DM, Inventory DM. And, then we con intergrate them.
#
# The Technology, HR, Marketing, Supply etc. are all part of Value chain. Everything that makes a business is part of its value.
#
#
#
# ![image-2.png](attachment:image-2.png)
#
#
# ## 2. What is Inventory Model?
#
# The Data Warehouse of Inventory data to keep track track of inventory by the end of day is called Inventory Model.
# Before, Making Dimension Model we need to know how do we wnat to track the inventor. Threr are three types:
#
# 1. Perodic Snapshot
# 2. Inventiry Transaction
# 3. Accumulating Snapshot
#
# ![image-4.png](attachment:image-4.png)
#
#
#
# ## 3. What is Enterprise DW Bus Matrix ?
#
# - “Family of dimensional models that share a comprehensive set of common, conformed dimensions”
# - “Master suite of standardized dimensions and facts with uniform interpretation across enterprise”
# - New dimensional models fit together like pieces of a puzzle
#
# ![image-6.png](attachment:image-6.png)
